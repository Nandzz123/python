# %%
a=int(input("enter the number:"))
if(a%7==0):
        print("divisible by 7")
else:
        print("not divisible")
# Out:
# eneter the number:3
# not divisible

# %%
n=input("enter the character:")
if n in ("a,e,i,o,u"):
    print("vowels")
else:
    print("not vowel")
# Out:
# enter the character:s
# not vowel

# %%
amt=int(input("enter the amount:"))
if(amt>5000):
    print("eligible for discount")
else:
    print("not eligible")
# Out:
# enter the amount:7000
# eligible for discount

# %%
a=int(input("enter the number:"))
if(a>=10 and a<=100):
  print(" lies between both")
else:
  print("none")
# Out:
# enter the number:9
# none

# %%
attend=int(input("enter the attendece:"))
if(attend>=75):
    print("eligible")
else:
    print("not eligible")
# Out:
# enter the attendece:50
# not eligible

# %%
alpha=input("enter the alphabet:")
if alpha.isupper():
    print("a is uppercase")
elif alpha.islower():
    print("a is lowercase")
else:
    print("none")
# Out:
# enter the alphabet:s
# a is lowercase

# %%
a=input("enter the string:")
b=input("enter another string:")
if(a==b):
    print("equal")
else:
    print("not equal")
# Out:
# enter the string:hello
# enter another string:hello
# equal

# %%
a=int(input("enter the number:"))
if(a>=100 and a<=999):
    print("3 digit number:")
else:
    print("not")
# Out:
# enter the number:800
# 3 digit number:
