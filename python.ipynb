# %%
age=int(input("enter your age:"))
print(age)
# Out:
# enter your age:25
# 25

# %%
num1=int(input("enter 1st num:"))
num2=int(input("enter 2 nd num:"))
sum=num1+num2
print(sum)
# Out:
# enter 1st num:2
# enter 2 nd num:4
# 6

# %%
num1=int(input("enter 1st num:"))
num2=int(input("enter 2 nd num:"))
sub=num1-num2
mul=num1*num2
div=num2/num1
print(sum)
print(mul)
print(div)
# Out:
# enter 1st num:2
# enter 2 nd num:3
# 6
# 6
# 1.5

# %%
length=int(input("enter the length of rectangle:"))
breadth=int(input("enter the bredth of rectangle:"))
area=length*breadth
print(area)
# Out:
# enter the length of rectangle:3
# enter the bredth of rectangle:5
# 15

# %%
num1=int(input("enter 1st num:"))
print(num1)
num2=int(input("enter 2st num:"))
print(num2)
sum=num1+num2
print("sum", sum)
# Out:
# enter 1st num:1
# 1
# enter 2st num:3
# 3
# sum 4

# %%
name="archana"
print(type(name))
# Out:
# <class 'str'>

# %%
name=45
print(type(name))
# Out:
# <class 'int'>

# %%
a=12
b="enter"
c=1.23
d=True
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
side=int(input("enter the side of square"))
area=side*side
print("area of square",area)
# Out:
# enter the side of square3
# area of square 9

# %%
base=int(input("enter the base of traingle"))
height=int(input("enter the height of traingle"))
area=1/2*base*height
print("area of traingle:",area)
# Out:
# enter the base of traingle3
# enter the height of traingle5
# area of traingle: 7.5

# %%
amount=int(input("enter the principal amt:"))
years=int(input("enter the number of years:"))
rate=int(input("enter the rate of interest:"))
interest=(amount*years*rate)/100
print(interest)
# Out:
# enter the principal amt:1
# enter the number of years:2
# enter the rate of interest:3
# 0.06

# %%
a=int(input("enter the integer:"))
previous=a-1
next=a+1
print("enter  the previous number:",previous)
print("enter the next number:",next)
# Out:
# enter the integer:2
# enter  the previous number: 1
# enter the next number: 3
