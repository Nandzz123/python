# %%
a=1
b=2
sum=a+b
print(sum)
# Out:
# 3

# %%
diff=a-b
print(diff)
# Out:
# -1

# %%
mul=a*b
print(mul)
# Out:
# 2

# %%
quotient=a/b
print(quotient)
remainder=a%b
print(remainder)
# Out:
# 0.5
# 1

# %%
r=int(input("enter the radius of circle:"))
area=3.14*r*r
print(area)
# Out:
# enter the radius of circle:2
# 12.56

# %%
a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
c=int(input("enter the third number:"))
average=a+b+c/3
print(average)
# Out:
# enter the first number:2
# enter the second number:3
# enter the third number:1
# 5.333333333333333

# %%
a=int(input('enter the temparature:'))
faren=(a*(9/5)+32)
print(faren)
# Out:
# enter the temparature:2
# 35.6
